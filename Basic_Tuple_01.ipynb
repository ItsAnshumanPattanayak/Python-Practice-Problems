# %% [markdown]
# # make a tuple with value 1,22,101,"anshuman",3.14,True,"rathore" so your task is to change the value "rathore" to "pattanayak"

# %%
tpl = (1,22,101,"anshuman",3.14,True,"rathore")

# %%
tpl
# Out:
# (1, 22, 101, 'anshuman', 3.14, True, 'rathore')

# %%
reverse_tpl = list(tpl) #converting tuple to list

# %%
reverse_tpl
# Out:
# [1, 22, 101, 'anshuman', 3.14, True, 'rathore']

# %%
reverse_tpl [6] = "pattanayak"

# %%
reverse_tpl
# Out:
# [1, 22, 101, 'anshuman', 3.14, True, 'pattanayak']

# %%
reverse_convert = tuple(reverse_tpl)

# %%
type(reverse_convert)
# Out:
# tuple
