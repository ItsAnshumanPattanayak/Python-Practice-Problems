# %%
n=2
for i in range (n):
  print("*")
# Out:
# *
# *

# %%
# ['***']
empty_list = [] # after 1 loop ['*'] after 2nd loop ['*'(this is present in first loop =), '*']
n=3
empty_list.append("*"*n)
print(empty_list)
# Out:
# ['***']

# %%
# ['***','***'] n=2 , m=3
empty_list = []
n=2
m=3
for i in range (0,n):

  empty_list.append("*"*m)
print(empty_list)
# Out:
# ['***', '***']

# %%
# ['***','***','***']
empty = []
n=3
for i in range (n):
  empty.append("*"*n)
print(empty)
# Out:
# ['***', '***', '***']

# %%
# ['***','###','***']  # stupid method
empty = []
a=3
b=3
c=3
for i in range(a-2):
  empty.append("*"*a)
for j in range(b-2):
  empty.append("#"*b)
for k in range(c-2):
  empty.append("*"*c)
print(empty)
# Out:
# ['***', '###', '***']

# %%
# ['***','###','***']
empty = []
n=3
m=3

for i in range (n):
  if i%2 == 0 :
    empty.append("*"*m)
  else :
    empty.append("#"*m)
print(empty)
# Out:
# ['***', '###', '***']

# %%
# ['***','***','###']
empty = []
n=3
m=3
for i in range (n):
  if i<2 :
    empty.append("*"*m)
  else :
    empty.append("#"*m)
print(empty)
# Out:
# ['***', '***', '###']
